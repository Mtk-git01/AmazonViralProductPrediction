# %% [markdown]
# ## Robust Data Downloader
# - Resume from the last stopped position
#
# - Skip already downloaded products
#
# - Save a list of failed ASINs

# %%
import pickle
import os
import keepa
import time
import datetime
import pandas as pd
import numpy as np
from tqdm import tqdm
import json
import logging

# API Setup
accesskey = 'bijj0cgn2715qdc3hftclnv9s04282ialobgj7gau50f5atp0qe3qklfvdjxxxxx'
api = keepa.Keepa(accesskey)

# File paths setup
base_path = '/Users/data/'
raw_data_path = os.path.join(base_path, 'raw_data')
processed_data_path = os.path.join(base_path, 'processed_data')
asin_file_path = os.path.join(base_path, 'pet_asin_list.txt')  # Path to your ASIN list file
progress_file = os.path.join(base_path, 'download_progress.json')
# Out:
# 2025-01-09 21:56:46,989 - INFO - Connecting to keepa using key ending in j2uehv
# 2025-01-09 21:56:47,460 - DEBUG - 0 tokens consumed
# 2025-01-09 21:56:47,462 - INFO - 60 tokens remain

# %%
# Setup logging
logging.basicConfig(
    level=logging.INFO,
    format='%(asctime)s - %(levelname)s - %(message)s',
    handlers=[
        logging.FileHandler('keepa_download.log'),
        logging.StreamHandler()
    ]
)


# Create directories if they don't exist
for path in [raw_data_path, processed_data_path]:
    os.makedirs(path, exist_ok=True)

def load_progress():
    """Load download progress from file"""
    if os.path.exists(progress_file):
        with open(progress_file, 'r') as f:
            return json.load(f)
    return {'completed': [], 'failed': [], 'last_index': 0}

def save_progress(progress):
    """Save download progress to file"""
    with open(progress_file, 'w') as f:
        json.dump(progress, f)

def read_asin_list(file_path):
    """
    Read ASINs from a text file
    Args:
        file_path (str): Path to the text file containing ASINs
    Returns:
        list: List of ASINs
    """
    try:
        with open(file_path, 'r') as f:
            # Read lines, clean special characters, and remove empty lines
            asins = []
            for line in f.readlines():
                # Clean the ASIN: remove whitespace and special characters
                asin = line.strip().strip('\\{}').strip()
                if asin and len(asin) == 10:  # Valid ASINs are 10 characters
                    asins.append(asin)
                else:
                    logging.warning(f"Skipping invalid ASIN: {asin}")

        logging.info(f"Successfully loaded {len(asins)} valid ASINs from {file_path}")
        return asins
    except Exception as e:
        logging.error(f"Error reading ASIN file: {str(e)}")
        return []

def download_product_data(asins, max_retries=3, retry_delay=60):
    """
    Download and save product data from Keepa API with retry mechanism
    Args:
        asins (list): List of Amazon ASINs to download
        max_retries (int): Maximum number of retries per ASIN
        retry_delay (int): Delay in seconds between retries
    """
    # Load previous progress
    progress = load_progress()
    start_index = progress['last_index']

    total = len(asins)
    for index, asin in enumerate(asins[start_index:], start=start_index):
        if asin in progress['completed']:
            logging.info(f"[{index+1}/{total}] ASIN {asin} already downloaded, skipping")
            continue

        retries = 0
        while retries < max_retries:
            try:
                # Check if data already exists
                pickle_path = os.path.join(raw_data_path, f'{asin}_raw.pkl')

                if os.path.exists(pickle_path):
                    logging.info(f"[{index+1}/{total}] Data for ASIN {asin} already exists, skipping")
                    progress['completed'].append(asin)
                    break

                # Query product data
                products = api.query(asin, history=True, offers=20)
                product = products[0]

                # Save raw data using pickle
                with open(pickle_path, 'wb') as f:
                    pickle.dump(product, f)

                logging.info(f"[{index+1}/{total}] Data saved for ASIN {asin}")
                progress['completed'].append(asin)

                # Update progress
                progress['last_index'] = index
                save_progress(progress)

                # Sleep to respect API limits (1 token per minute)
                time.sleep(60)
                break

            except Exception as e:
                retries += 1
                error_msg = f"[{index+1}/{total}] Error processing ASIN {asin} (Attempt {retries}/{max_retries}): {str(e)}"
                if retries < max_retries:
                    logging.warning(f"{error_msg} - Retrying in {retry_delay} seconds...")
                    time.sleep(retry_delay)
                else:
                    logging.error(error_msg)
                    if asin not in progress['failed']:
                        progress['failed'].append(asin)
                    save_progress(progress)

    # Final report
    logging.info("\nDownload Summary:")
    logging.info(f"Total ASINs: {total}")
    logging.info(f"Successfully downloaded: {len(progress['completed'])}")
    logging.info(f"Failed: {len(progress['failed'])}")
    if progress['failed']:
        logging.info("\nFailed ASINs:")
        for asin in progress['failed']:
            logging.info(asin)

# %%
# Run the download
if __name__ == "__main__":
    asins = read_asin_list(asin_file_path)
    if asins:
        logging.info(f"Starting download for {len(asins)} ASINs...")
        download_product_data(asins)
        logging.info("Download process completed!")
# Out:
# 2025-01-09 21:57:46,993 - INFO - Successfully loaded 7512 valid ASINs from /Users/takedownccp/Documents/Cursor/DDU/data/pet_asin_list.txt
# 2025-01-09 21:57:46,994 - INFO - Starting download for 7512 ASINs...
# 2025-01-09 21:57:46,995 - INFO - [67/7512] ASIN B07RVD63J1 already downloaded, skipping
# 2025-01-09 21:57:46,999 - DEBUG - Executing single product query
# 2025-01-09 21:57:47,000 - DEBUG - Estimated time to complete 1 request(s) is 0.50 minutes
# 2025-01-09 21:57:47,000 - DEBUG - 	with a refill rate of 1 token(s) per minute
#   0%|          | 0/1 [00:00<?, ?it/s]2025-01-09 21:57:47,415 - DEBUG - 0 tokens consumed
# 2025-01-09 21:57:49,144 - DEBUG - 1 tokens consumed
# 100%|██████████| 1/1 [00:02<00:00,  2.18s/it]
# 2025-01-09 21:57:49,213 - INFO - [68/7512] Data saved for ASIN B089PM6FRC
# 2025-01-09 21:58:49,226 - DEBUG - Executing single product query
# 2025-01-09 21:58:49,241 - DEBUG - Estimated time to complete 1 request(s) is 0.50 minutes
# 2025-01-09 21:58:49,242 - DEBUG - 	with a refill rate of 1 token(s) per minute
#   0%|          | 0/1 [00:00<?, ?it/s]2025-01-09 21:58:49,726 - DEBUG - 0 tokens consumed
# 2025-01-09 21:59:00,027 - WARNING - [69/7512] Error processing ASIN B08RQDM2C7 (Attempt 1/3): HTTPSConnectionPool(host='api.keepa.com', port=443): Read timed out. (read timeout=10.0) - Retrying in 60 seconds...
# 2025-01-09 22:00:00,039 - DEBUG - Executing single product query
# 2025-01-09 22:00:00,077 - DEBUG - Estimated time to complete 1 request(s) is 0.50 minutes
# 2025-01-09 22:00:00,078 - DEBUG - 	with a refill rate of 1 token(s) per minute
# 2025-01-09 22:00:00,490 - DEBUG - 0 tokens consumed
#   0%|          | 0/1 [01:12<?, ?it/s]
# 2025-01-09 22:00:01,324 - DEBUG - 5 tokens consumed
# 100%|██████████| 1/1 [00:01<00:00,  1.28s/it]
# 2025-01-09 22:00:01,395 - INFO - [69/7512] Data saved for ASIN B08RQDM2C7
# 2025-01-09 22:01:01,409 - DEBUG - Executing single product query
# 2025-01-09 22:01:01,423 - DEBUG - Estimated time to complete 1 request(s) is 0.50 minutes
# 2025-01-09 22:01:01,424 - DEBUG - 	with a refill rate of 1 token(s) per minute
#   0%|          | 0/1 [00:00<?, ?it/s]2025-01-09 22:01:01,834 - DEBUG - 0 tokens consumed
# 2025-01-09 22:01:10,409 - DEBUG - 6 tokens consumed
# 100%|██████████| 1/1 [00:09<00:00,  9.03s/it]
# 2025-01-09 22:01:10,476 - INFO - [70/7512] Data saved for ASIN B07DGYXWX1
# 2025-01-09 22:02:10,503 - DEBUG - Executing single product query
# 2025-01-09 22:02:10,536 - DEBUG - Estimated time to complete 1 request(s) is 0.50 minutes
# 2025-01-09 22:02:10,537 - DEBUG - 	with a refill rate of 1 token(s) per minute
#   0%|          | 0/1 [00:00<?, ?it/s]2025-01-09 22:02:14,494 - DEBUG - 0 tokens consumed
# 2025-01-09 22:02:24,822 - WARNING - [71/7512] Error processing ASIN B01BMBPOJ2 (Attempt 1/3): HTTPSConnectionPool(host='api.keepa.com', port=443): Read timed out. (read timeout=10.0) - Retrying in 60 seconds...
# 2025-01-09 22:03:24,834 - DEBUG - Executing single product query
# 2025-01-09 22:03:24,839 - DEBUG - Estimated time to complete 1 request(s) is 0.50 minutes
# 2025-01-09 22:03:24,840 - DEBUG - 	with a refill rate of 1 token(s) per minute
# 2025-01-09 22:03:25,270 - DEBUG - 0 tokens consumed
#   0%|          | 0/1 [01:15<?, ?it/s]
# 2025-01-09 22:03:26,109 - DEBUG - 5 tokens consumed
# 100%|██████████| 1/1 [00:01<00:00,  1.31s/it]
# 2025-01-09 22:03:26,200 - INFO - [71/7512] Data saved for ASIN B01BMBPOJ2
# 2025-01-09 22:04:26,230 - DEBUG - Executing single product query
# 2025-01-09 22:04:26,252 - DEBUG - Estimated time to complete 1 request(s) is 0.50 minutes
# 2025-01-09 22:04:26,253 - DEBUG - 	with a refill rate of 1 token(s) per minute
#   0%|          | 0/1 [00:00<?, ?it/s]2025-01-09 22:04:26,669 - DEBUG - 0 tokens consumed
# 2025-01-09 22:04:37,315 - DEBUG - 6 tokens consumed
# 100%|██████████| 1/1 [00:11<00:00, 11.10s/it]
# 2025-01-09 22:04:37,388 - INFO - [72/7512] Data saved for ASIN B000SSXDBM
# 2025-01-09 22:05:37,403 - DEBUG - Executing single product query
# 2025-01-09 22:05:37,443 - DEBUG - Estimated time to complete 1 request(s) is 0.50 minutes
# 2025-01-09 22:05:37,444 - DEBUG - 	with a refill rate of 1 token(s) per minute
#   0%|          | 0/1 [00:00<?, ?it/s]2025-01-09 22:05:37,854 - DEBUG - 0 tokens consumed
# 2025-01-09 22:05:44,392 - DEBUG - 6 tokens consumed
# 100%|██████████| 1/1 [00:07<00:00,  7.01s/it]
# 2025-01-09 22:05:44,492 - INFO - [73/7512] Data saved for ASIN B07FJQYVZ6
# 2025-01-09 22:06:44,537 - DEBUG - Executing single product query
# 2025-01-09 22:06:44,550 - DEBUG - Estimated time to complete 1 request(s) is 0.50 minutes
# 2025-01-09 22:06:44,551 - DEBUG - 	with a refill rate of 1 token(s) per minute
#   0%|          | 0/1 [00:00<?, ?it/s]2025-01-09 22:06:44,979 - DEBUG - 0 tokens consumed
# 2025-01-09 22:06:47,066 - DEBUG - 1 tokens consumed
# 100%|██████████| 1/1 [00:02<00:00,  2.56s/it]
# 2025-01-09 22:06:47,144 - INFO - [74/7512] Data saved for ASIN B0BMBC1FJX
# 2025-01-09 22:07:47,160 - DEBUG - Executing single product query
# 2025-01-09 22:07:47,174 - DEBUG - Estimated time to complete 1 request(s) is 0.50 minutes
# 2025-01-09 22:07:47,175 - DEBUG - 	with a refill rate of 1 token(s) per minute
#   0%|          | 0/1 [00:00<?, ?it/s]2025-01-09 22:07:47,583 - DEBUG - 0 tokens consumed
# 2025-01-09 22:07:48,421 - DEBUG - 5 tokens consumed
# 100%|██████████| 1/1 [00:01<00:00,  1.28s/it]
# 2025-01-09 22:07:48,491 - INFO - [75/7512] Data saved for ASIN B082L3QQCB
# 2025-01-09 22:08:48,523 - DEBUG - Executing single product query
# 2025-01-09 22:08:48,530 - DEBUG - Estimated time to complete 1 request(s) is 0.50 minutes
# 2025-01-09 22:08:48,531 - DEBUG - 	with a refill rate of 1 token(s) per minute
#   0%|          | 0/1 [00:00<?, ?it/s]2025-01-09 22:08:48,953 - DEBUG - 0 tokens consumed
# 2025-01-09 22:08:54,536 - DEBUG - 6 tokens consumed
# 100%|██████████| 1/1 [00:06<00:00,  6.01s/it]
# 2025-01-09 22:08:54,556 - INFO - [76/7512] Data saved for ASIN B0CDLL9WN6
# 2025-01-09 22:09:54,572 - DEBUG - Executing single product query
# 2025-01-09 22:09:54,577 - DEBUG - Estimated time to complete 1 request(s) is 0.50 minutes
# 2025-01-09 22:09:54,578 - DEBUG - 	with a refill rate of 1 token(s) per minute
#   0%|          | 0/1 [00:00<?, ?it/s]2025-01-09 22:09:56,086 - DEBUG - 0 tokens consumed
# 2025-01-09 22:10:04,510 - DEBUG - 12 tokens consumed
# 100%|██████████| 1/1 [00:09<00:00,  9.98s/it]
# 2025-01-09 22:10:04,620 - INFO - [77/7512] Data saved for ASIN B006W6YHYQ
# 2025-01-09 22:11:04,650 - DEBUG - Executing single product query
# 2025-01-09 22:11:04,670 - DEBUG - Estimated time to complete 1 request(s) is 3.24 minutes
# 2025-01-09 22:11:04,671 - DEBUG - 	with a refill rate of 1 token(s) per minute
#   0%|          | 0/1 [00:00<?, ?it/s]2025-01-09 22:11:05,069 - DEBUG - 0 tokens consumed
# 2025-01-09 22:11:05,072 - WARNING - Waiting 127 seconds for additional tokens
# 2025-01-09 22:13:12,286 - DEBUG - 0 tokens consumed
# 2025-01-09 22:13:20,089 - DEBUG - 6 tokens consumed
# 100%|██████████| 1/1 [02:15<00:00, 135.47s/it]
# 2025-01-09 22:13:20,164 - INFO - [78/7512] Data saved for ASIN B097S6ZFZB
# 2025-01-09 22:14:20,188 - DEBUG - Executing single product query
# 2025-01-09 22:14:20,203 - DEBUG - Estimated time to complete 1 request(s) is 5.99 minutes
# 2025-01-09 22:14:20,204 - DEBUG - 	with a refill rate of 1 token(s) per minute
#   0%|          | 0/1 [00:00<?, ?it/s]2025-01-09 22:14:20,619 - DEBUG - 0 tokens consumed
# 2025-01-09 22:14:20,620 - WARNING - Waiting 292 seconds for additional tokens
# 2025-01-09 22:19:13,139 - DEBUG - 0 tokens consumed
# 2025-01-09 22:19:22,779 - DEBUG - 6 tokens consumed
# 100%|██████████| 1/1 [05:02<00:00, 302.61s/it]
# 2025-01-09 22:19:22,837 - INFO - [79/7512] Data saved for ASIN B0BF7NC56Z
# 2025-01-09 22:20:22,856 - DEBUG - Executing single product query
# 2025-01-09 22:20:22,859 - DEBUG - Estimated time to complete 1 request(s) is 5.99 minutes
# 2025-01-09 22:20:22,860 - DEBUG - 	with a refill rate of 1 token(s) per minute
#   0%|          | 0/1 [00:00<?, ?it/s]2025-01-09 22:20:23,276 - DEBUG - 0 tokens consumed
# 2025-01-09 22:20:23,278 - WARNING - Waiting 291 seconds for additional tokens
# 2025-01-09 22:25:14,305 - DEBUG - 0 tokens consumed
# 2025-01-09 22:25:19,642 - DEBUG - 6 tokens consumed
# 100%|██████████| 1/1 [04:56<00:00, 296.81s/it]
# 2025-01-09 22:25:19,690 - INFO - [80/7512] Data saved for ASIN B0BGJHMJHW
# 2025-01-09 22:26:19,718 - DEBUG - Executing single product query
# 2025-01-09 22:26:19,751 - DEBUG - Estimated time to complete 1 request(s) is 5.99 minutes
# 2025-01-09 22:26:19,752 - DEBUG - 	with a refill rate of 1 token(s) per minute
#   0%|          | 0/1 [00:00<?, ?it/s]2025-01-09 22:26:20,186 - DEBUG - 0 tokens consumed
# 2025-01-09 22:26:20,187 - WARNING - Waiting 295 seconds for additional tokens
# 2025-01-09 22:31:15,555 - DEBUG - 0 tokens consumed
# 2025-01-09 22:31:25,891 - WARNING - [81/7512] Error processing ASIN B0CWTVJ6XJ (Attempt 1/3): HTTPSConnectionPool(host='api.keepa.com', port=443): Read timed out. (read timeout=10.0) - Retrying in 60 seconds...
# 2025-01-09 22:32:25,913 - DEBUG - Executing single product query
# 2025-01-09 22:32:25,943 - DEBUG - Estimated time to complete 1 request(s) is 0.50 minutes
# 2025-01-09 22:32:25,944 - DEBUG - 	with a refill rate of 1 token(s) per minute
# 2025-01-09 22:32:26,406 - DEBUG - 0 tokens consumed
# 2025-01-09 22:32:26,408 - WARNING - Waiting 290 seconds for additional tokens
# 2025-01-09 22:37:16,737 - DEBUG - 0 tokens consumed
# 2025-01-09 22:37:19,075 - DEBUG - 5 tokens consumed
# 100%|██████████| 1/1 [04:53<00:00, 293.18s/it]
#   0%|          | 0/1 [10:59<?, ?it/s]
# 2025-01-09 22:37:19,154 - INFO - [81/7512] Data saved for ASIN B0CWTVJ6XJ
# 2025-01-09 22:38:19,175 - DEBUG - Executing single product query
# 2025-01-09 22:38:19,192 - DEBUG - Estimated time to complete 1 request(s) is 5.00 minutes
# 2025-01-09 22:38:19,193 - DEBUG - 	with a refill rate of 1 token(s) per minute
#   0%|          | 0/1 [00:00<?, ?it/s]2025-01-09 22:38:19,617 - DEBUG - 0 tokens consumed
# 2025-01-09 22:38:19,619 - WARNING - Waiting 238 seconds for additional tokens
# 2025-01-09 22:42:18,149 - DEBUG - 0 tokens consumed
# 2025-01-09 22:42:28,464 - WARNING - [82/7512] Error processing ASIN B01AVI1I06 (Attempt 1/3): HTTPSConnectionPool(host='api.keepa.com', port=443): Read timed out. (read timeout=10.0) - Retrying in 60 seconds...
# 2025-01-09 22:43:28,489 - DEBUG - Executing single product query
# 2025-01-09 22:43:28,510 - DEBUG - Estimated time to complete 1 request(s) is 0.50 minutes
# 2025-01-09 22:43:28,510 - DEBUG - 	with a refill rate of 1 token(s) per minute
# 2025-01-09 22:43:29,601 - DEBUG - 0 tokens consumed
# 2025-01-09 22:43:29,604 - WARNING - Waiting 289 seconds for additional tokens
# 2025-01-09 22:48:19,172 - DEBUG - 0 tokens consumed
#   0%|          | 0/1 [10:00<?, ?it/s]
# 2025-01-09 22:48:20,189 - DEBUG - 5 tokens consumed
# 100%|██████████| 1/1 [04:51<00:00, 291.77s/it]
# 2025-01-09 22:48:20,388 - INFO - [82/7512] Data saved for ASIN B01AVI1I06
# 2025-01-09 22:49:20,399 - DEBUG - Executing single product query
# 2025-01-09 22:49:20,417 - DEBUG - Estimated time to complete 1 request(s) is 4.99 minutes
# 2025-01-09 22:49:20,417 - DEBUG - 	with a refill rate of 1 token(s) per minute
#   0%|          | 0/1 [00:00<?, ?it/s]2025-01-09 22:49:21,244 - DEBUG - 0 tokens consumed
# 2025-01-09 22:49:21,248 - WARNING - Waiting 239 seconds for additional tokens
# 2025-01-09 22:53:20,596 - DEBUG - 0 tokens consumed
# 2025-01-09 22:53:30,899 - DEBUG - 6 tokens consumed
# 100%|██████████| 1/1 [04:10<00:00, 250.53s/it]
# 2025-01-09 22:53:31,003 - INFO - [83/7512] Data saved for ASIN B000VDR8LA
# 2025-01-09 22:54:31,048 - DEBUG - Executing single product query
# 2025-01-09 22:54:31,064 - DEBUG - Estimated time to complete 1 request(s) is 5.99 minutes
# 2025-01-09 22:54:31,065 - DEBUG - 	with a refill rate of 1 token(s) per minute
#   0%|          | 0/1 [00:00<?, ?it/s]2025-01-09 22:54:31,488 - DEBUG - 0 tokens consumed
# 2025-01-09 22:54:31,490 - WARNING - Waiting 289 seconds for additional tokens
# 2025-01-09 22:59:21,390 - DEBUG - 0 tokens consumed
# 2025-01-09 22:59:29,374 - DEBUG - 6 tokens consumed
# 100%|██████████| 1/1 [04:58<00:00, 298.36s/it]
# 2025-01-09 22:59:29,460 - INFO - [84/7512] Data saved for ASIN B006WW861K
# 2025-01-09 23:00:29,482 - DEBUG - Executing single product query
# 2025-01-09 23:00:29,493 - DEBUG - Estimated time to complete 1 request(s) is 5.99 minutes
# 2025-01-09 23:00:29,495 - DEBUG - 	with a refill rate of 1 token(s) per minute
#   0%|          | 0/1 [00:00<?, ?it/s]2025-01-09 23:00:29,933 - DEBUG - 0 tokens consumed
# 2025-01-09 23:00:29,934 - WARNING - Waiting 292 seconds for additional tokens
# 2025-01-09 23:05:22,589 - DEBUG - 0 tokens consumed
# 2025-01-09 23:05:30,051 - DEBUG - 6 tokens consumed
# 100%|██████████| 1/1 [05:00<00:00, 300.61s/it]
# 2025-01-09 23:05:30,156 - INFO - [85/7512] Data saved for ASIN B00N240SQ2
# 2025-01-09 23:06:30,178 - DEBUG - Executing single product query
# 2025-01-09 23:06:30,195 - DEBUG - Estimated time to complete 1 request(s) is 5.99 minutes
# 2025-01-09 23:06:30,196 - DEBUG - 	with a refill rate of 1 token(s) per minute
#   0%|          | 0/1 [00:00<?, ?it/s]2025-01-09 23:06:30,666 - DEBUG - 0 tokens consumed
# 2025-01-09 23:06:30,669 - WARNING - Waiting 293 seconds for additional tokens
# 2025-01-09 23:11:23,760 - DEBUG - 0 tokens consumed
# 2025-01-09 23:11:34,072 - WARNING - [86/7512] Error processing ASIN B013T6P7M2 (Attempt 1/3): HTTPSConnectionPool(host='api.keepa.com', port=443): Read timed out. (read timeout=10.0) - Retrying in 60 seconds...
# 2025-01-09 23:12:34,100 - DEBUG - Executing single product query
# 2025-01-09 23:12:34,105 - DEBUG - Estimated time to complete 1 request(s) is 0.50 minutes
# 2025-01-09 23:12:34,106 - DEBUG - 	with a refill rate of 1 token(s) per minute
# 2025-01-09 23:12:34,691 - DEBUG - 0 tokens consumed
# 2025-01-09 23:12:34,693 - WARNING - Waiting 290 seconds for additional tokens
# 2025-01-09 23:17:25,027 - DEBUG - 0 tokens consumed
#   0%|          | 0/1 [10:55<?, ?it/s]
# 2025-01-09 23:17:25,878 - DEBUG - 5 tokens consumed
# 100%|██████████| 1/1 [04:51<00:00, 291.82s/it]
# 2025-01-09 23:17:25,968 - INFO - [86/7512] Data saved for ASIN B013T6P7M2
# 2025-01-09 23:18:25,995 - DEBUG - Executing single product query
# 2025-01-09 23:18:26,011 - DEBUG - Estimated time to complete 1 request(s) is 4.99 minutes
# 2025-01-09 23:18:26,012 - DEBUG - 	with a refill rate of 1 token(s) per minute
#   0%|          | 0/1 [00:00<?, ?it/s]2025-01-09 23:18:26,439 - DEBUG - 0 tokens consumed
# 2025-01-09 23:18:26,440 - WARNING - Waiting 239 seconds for additional tokens
# 2025-01-09 23:22:26,196 - DEBUG - 0 tokens consumed
# 2025-01-09 23:22:33,459 - DEBUG - 6 tokens consumed
# 100%|██████████| 1/1 [04:07<00:00, 247.50s/it]
# 2025-01-09 23:22:33,561 - INFO - [87/7512] Data saved for ASIN B079QCXTXF
# 2025-01-09 23:23:33,587 - DEBUG - Executing single product query
# 2025-01-09 23:23:33,592 - DEBUG - Estimated time to complete 1 request(s) is 5.99 minutes
# 2025-01-09 23:23:33,593 - DEBUG - 	with a refill rate of 1 token(s) per minute
#   0%|          | 0/1 [00:00<?, ?it/s]2025-01-09 23:23:34,025 - DEBUG - 0 tokens consumed
# 2025-01-09 23:23:34,026 - WARNING - Waiting 293 seconds for additional tokens
# 2025-01-09 23:28:27,358 - DEBUG - 0 tokens consumed
# 2025-01-09 23:28:37,680 - WARNING - [88/7512] Error processing ASIN B00JT3TP1O (Attempt 1/3): HTTPSConnectionPool(host='api.keepa.com', port=443): Read timed out. (read timeout=10.0) - Retrying in 60 seconds...
# 2025-01-09 23:29:37,698 - DEBUG - Executing single product query
# 2025-01-09 23:29:37,715 - DEBUG - Estimated time to complete 1 request(s) is 0.01 minutes
# 2025-01-09 23:29:37,716 - DEBUG - 	with a refill rate of 1 token(s) per minute
# 2025-01-09 23:29:38,149 - DEBUG - 0 tokens consumed
# 2025-01-09 23:29:38,152 - WARNING - Waiting 290 seconds for additional tokens
# 2025-01-09 23:34:29,319 - DEBUG - 0 tokens consumed
#   0%|          | 0/1 [10:56<?, ?it/s]
# 2025-01-09 23:34:30,286 - DEBUG - 5 tokens consumed
# 100%|██████████| 1/1 [04:52<00:00, 292.63s/it]
# 2025-01-09 23:34:30,398 - INFO - [88/7512] Data saved for ASIN B00JT3TP1O
# 2025-01-09 23:35:30,424 - DEBUG - Executing single product query
# 2025-01-09 23:35:30,458 - DEBUG - Estimated time to complete 1 request(s) is 4.99 minutes
# 2025-01-09 23:35:30,459 - DEBUG - 	with a refill rate of 1 token(s) per minute
#   0%|          | 0/1 [00:00<?, ?it/s]2025-01-09 23:35:30,893 - DEBUG - 0 tokens consumed
# 2025-01-09 23:35:30,894 - WARNING - Waiting 239 seconds for additional tokens
# 2025-01-09 23:39:30,388 - DEBUG - 0 tokens consumed
# 2025-01-09 23:39:40,711 - WARNING - [89/7512] Error processing ASIN B07M623FD4 (Attempt 1/3): HTTPSConnectionPool(host='api.keepa.com', port=443): Read timed out. (read timeout=10.0) - Retrying in 60 seconds...
# 2025-01-09 23:40:40,735 - DEBUG - Executing single product query
# 2025-01-09 23:40:40,754 - DEBUG - Estimated time to complete 1 request(s) is 0.50 minutes
# 2025-01-09 23:40:40,756 - DEBUG - 	with a refill rate of 1 token(s) per minute
# 2025-01-09 23:40:41,375 - DEBUG - 0 tokens consumed
# 2025-01-09 23:40:41,376 - WARNING - Waiting 290 seconds for additional tokens
# 2025-01-09 23:45:31,657 - DEBUG - 0 tokens consumed
# 2025-01-09 23:45:32,408 - DEBUG - 5 tokens consumed
# 100%|██████████| 1/1 [04:51<00:00, 291.69s/it]
#   0%|          | 0/1 [10:02<?, ?it/s]
# 2025-01-09 23:45:32,476 - INFO - [89/7512] Data saved for ASIN B07M623FD4
# 2025-01-09 23:46:32,499 - DEBUG - Executing single product query
# 2025-01-09 23:46:32,523 - DEBUG - Estimated time to complete 1 request(s) is 4.99 minutes
# 2025-01-09 23:46:32,523 - DEBUG - 	with a refill rate of 1 token(s) per minute
#   0%|          | 0/1 [00:00<?, ?it/s]2025-01-09 23:46:32,946 - DEBUG - 0 tokens consumed
# 2025-01-09 23:46:32,947 - WARNING - Waiting 239 seconds for additional tokens
# 2025-01-09 23:50:32,627 - DEBUG - 0 tokens consumed
# 2025-01-09 23:50:33,374 - DEBUG - 5 tokens consumed
# 100%|██████████| 1/1 [04:00<00:00, 240.89s/it]
# 2025-01-09 23:50:33,437 - INFO - [90/7512] Data saved for ASIN B0C5Y7XFQ7
# 2025-01-09 23:51:33,458 - DEBUG - Executing single product query
# 2025-01-09 23:51:33,465 - DEBUG - Estimated time to complete 1 request(s) is 4.99 minutes
# 2025-01-09 23:51:33,466 - DEBUG - 	with a refill rate of 1 token(s) per minute
#   0%|          | 0/1 [00:00<?, ?it/s]2025-01-09 23:51:33,887 - DEBUG - 0 tokens consumed
# 2025-01-09 23:51:33,889 - WARNING - Waiting 239 seconds for additional tokens
# 2025-01-09 23:55:33,633 - DEBUG - 0 tokens consumed
# 2025-01-09 23:55:39,808 - DEBUG - 6 tokens consumed
# 100%|██████████| 1/1 [04:06<00:00, 246.39s/it]
# 2025-01-09 23:55:39,905 - INFO - [91/7512] Data saved for ASIN B003YKWIGC
# 2025-01-09 23:56:39,933 - DEBUG - Executing single product query
# 2025-01-09 23:56:39,954 - DEBUG - Estimated time to complete 1 request(s) is 5.99 minutes
# 2025-01-09 23:56:39,955 - DEBUG - 	with a refill rate of 1 token(s) per minute
#   0%|          | 0/1 [00:00<?, ?it/s]2025-01-09 23:56:40,369 - DEBUG - 0 tokens consumed
# 2025-01-09 23:56:40,372 - WARNING - Waiting 294 seconds for additional tokens
# 2025-01-10 00:01:34,611 - DEBUG - 0 tokens consumed
# 2025-01-10 00:01:42,091 - DEBUG - 6 tokens consumed
# 100%|██████████| 1/1 [05:02<00:00, 302.18s/it]
# 2025-01-10 00:01:42,150 - INFO - [92/7512] Data saved for ASIN B0BW5SFYMG
# 2025-01-10 00:02:42,185 - DEBUG - Executing single product query
# 2025-01-10 00:02:42,190 - DEBUG - Estimated time to complete 1 request(s) is 5.99 minutes
# 2025-01-10 00:02:42,193 - DEBUG - 	with a refill rate of 1 token(s) per minute
#   0%|          | 0/1 [00:00<?, ?it/s]2025-01-10 00:02:42,659 - DEBUG - 0 tokens consumed
# 2025-01-10 00:02:42,660 - WARNING - Waiting 293 seconds for additional tokens
# 2025-01-10 00:07:35,854 - DEBUG - 0 tokens consumed
# 2025-01-10 00:07:46,183 - WARNING - [93/7512] Error processing ASIN B000V5NVQ4 (Attempt 1/3): HTTPSConnectionPool(host='api.keepa.com', port=443): Read timed out. (read timeout=10.0) - Retrying in 60 seconds...
# 2025-01-10 00:08:46,201 - DEBUG - Executing single product query
# 2025-01-10 00:08:46,215 - DEBUG - Estimated time to complete 1 request(s) is 0.01 minutes
# 2025-01-10 00:08:46,216 - DEBUG - 	with a refill rate of 1 token(s) per minute
# 2025-01-10 00:08:46,648 - DEBUG - 0 tokens consumed
# 2025-01-10 00:08:46,650 - WARNING - Waiting 290 seconds for additional tokens
# 2025-01-10 00:13:37,695 - DEBUG - 0 tokens consumed
#   0%|          | 0/1 [10:56<?, ?it/s]
# 2025-01-10 00:13:38,540 - DEBUG - 5 tokens consumed
# 100%|██████████| 1/1 [04:52<00:00, 292.38s/it]
# 2025-01-10 00:13:38,670 - INFO - [93/7512] Data saved for ASIN B000V5NVQ4
# 2025-01-10 00:14:38,695 - DEBUG - Executing single product query
# 2025-01-10 00:14:38,713 - DEBUG - Estimated time to complete 1 request(s) is 4.99 minutes
# 2025-01-10 00:14:38,717 - DEBUG - 	with a refill rate of 1 token(s) per minute
#   0%|          | 0/1 [00:00<?, ?it/s]2025-01-10 00:14:39,291 - DEBUG - 0 tokens consumed
# 2025-01-10 00:14:39,294 - WARNING - Waiting 239 seconds for additional tokens
# 2025-01-10 00:18:38,674 - DEBUG - 0 tokens consumed
# 2025-01-10 00:18:48,986 - WARNING - [94/7512] Error processing ASIN B000OUNXXW (Attempt 1/3): HTTPSConnectionPool(host='api.keepa.com', port=443): Read timed out. (read timeout=10.0) - Retrying in 60 seconds...
# 2025-01-10 00:19:49,021 - DEBUG - Executing single product query
# 2025-01-10 00:19:49,027 - DEBUG - Estimated time to complete 1 request(s) is 0.50 minutes
# 2025-01-10 00:19:49,028 - DEBUG - 	with a refill rate of 1 token(s) per minute
# 2025-01-10 00:19:49,434 - DEBUG - 0 tokens consumed
#   0%|          | 0/1 [05:11<?, ?it/s]
# 2025-01-10 00:19:50,282 - DEBUG - 5 tokens consumed
# 100%|██████████| 1/1 [00:01<00:00,  1.29s/it]
# 2025-01-10 00:19:50,359 - INFO - [94/7512] Data saved for ASIN B000OUNXXW
# 2025-01-10 00:20:50,392 - DEBUG - Executing single product query
# 2025-01-10 00:20:50,401 - DEBUG - Estimated time to complete 1 request(s) is 4.82 minutes
# 2025-01-10 00:20:50,401 - DEBUG - 	with a refill rate of 1 token(s) per minute
#   0%|          | 0/1 [00:00<?, ?it/s]2025-01-10 00:20:50,826 - DEBUG - 0 tokens consumed
# 2025-01-10 00:20:50,827 - WARNING - Waiting 229 seconds for additional tokens
# 2025-01-10 00:24:40,309 - DEBUG - 0 tokens consumed
# 2025-01-10 00:24:48,027 - DEBUG - 6 tokens consumed
# 100%|██████████| 1/1 [03:57<00:00, 237.67s/it]
# 2025-01-10 00:24:48,108 - INFO - [95/7512] Data saved for ASIN B0716DFHDX
# 2025-01-10 00:25:48,123 - DEBUG - Executing single product query
# 2025-01-10 00:25:48,133 - DEBUG - Estimated time to complete 1 request(s) is 5.99 minutes
# 2025-01-10 00:25:48,134 - DEBUG - 	with a refill rate of 1 token(s) per minute
#   0%|          | 0/1 [00:00<?, ?it/s]2025-01-10 00:25:48,539 - DEBUG - 0 tokens consumed
# 2025-01-10 00:25:48,541 - WARNING - Waiting 292 seconds for additional tokens
# 2025-01-10 00:30:41,368 - DEBUG - 0 tokens consumed
# 2025-01-10 00:30:50,657 - DEBUG - 12 tokens consumed
# 100%|██████████| 1/1 [05:02<00:00, 302.57s/it]
# 2025-01-10 00:30:50,757 - INFO - [96/7512] Data saved for ASIN B001QCSHLK
# 2025-01-10 00:31:50,871 - DEBUG - Executing single product query
# 2025-01-10 00:31:50,879 - DEBUG - Estimated time to complete 1 request(s) is 11.99 minutes
# 2025-01-10 00:31:50,880 - DEBUG - 	with a refill rate of 1 token(s) per minute
#   0%|          | 0/1 [00:00<?, ?it/s]2025-01-10 00:31:51,309 - DEBUG - 0 tokens consumed
# 2025-01-10 00:31:51,312 - WARNING - Waiting 651 seconds for additional tokens
# 2025-01-10 00:42:42,580 - DEBUG - 0 tokens consumed
# Response from server: NOT_ENOUGH_TOKEN
# 2025-01-10 00:42:43,529 - DEBUG - 0 tokens consumed
# 2025-01-10 00:42:43,532 - WARNING - Waiting 1 seconds for additional tokens
# 2025-01-10 00:42:48,659 - DEBUG - 0 tokens consumed
# 2025-01-10 00:42:56,359 - DEBUG - 6 tokens consumed
# 100%|██████████| 1/1 [11:05<00:00, 665.54s/it]
# 2025-01-10 00:42:56,473 - INFO - [97/7512] Data saved for ASIN B0081KTPQQ
# 2025-01-10 00:43:56,485 - DEBUG - Executing single product query
# 2025-01-10 00:43:56,504 - DEBUG - Estimated time to complete 1 request(s) is 5.92 minutes
# 2025-01-10 00:43:56,504 - DEBUG - 	with a refill rate of 1 token(s) per minute
#   0%|          | 0/1 [00:00<?, ?it/s]2025-01-10 00:43:56,932 - DEBUG - 0 tokens consumed
# 2025-01-10 00:43:56,933 - WARNING - Waiting 288 seconds for additional tokens
# 2025-01-10 00:48:45,449 - DEBUG - 0 tokens consumed
# 2025-01-10 00:48:46,824 - DEBUG - 5 tokens consumed
# 100%|██████████| 1/1 [04:50<00:00, 290.38s/it]
# 2025-01-10 00:48:46,930 - INFO - [98/7512] Data saved for ASIN B01IRO7WR4
# 2025-01-10 00:49:46,938 - DEBUG - Executing single product query
# 2025-01-10 00:49:46,941 - DEBUG - Estimated time to complete 1 request(s) is 4.99 minutes
# 2025-01-10 00:49:46,942 - DEBUG - 	with a refill rate of 1 token(s) per minute
#   0%|          | 0/1 [00:00<?, ?it/s]2025-01-10 00:49:47,373 - DEBUG - 0 tokens consumed
# 2025-01-10 00:49:47,375 - WARNING - Waiting 239 seconds for additional tokens
# 2025-01-10 00:53:46,406 - DEBUG - 0 tokens consumed
# 2025-01-10 00:53:47,484 - DEBUG - 5 tokens consumed
# 100%|██████████| 1/1 [04:00<00:00, 240.57s/it]
# 2025-01-10 00:53:47,524 - INFO - [99/7512] Data saved for ASIN B0C33KN3FX
# 2025-01-10 00:54:47,535 - DEBUG - Executing single product query
# 2025-01-10 00:54:47,550 - DEBUG - Estimated time to complete 1 request(s) is 4.99 minutes
# 2025-01-10 00:54:47,551 - DEBUG - 	with a refill rate of 1 token(s) per minute
#   0%|          | 0/1 [00:00<?, ?it/s]2025-01-10 00:54:47,963 - DEBUG - 0 tokens consumed
# 2025-01-10 00:54:47,964 - WARNING - Waiting 239 seconds for additional tokens
# 2025-01-10 00:58:48,689 - DEBUG - 0 tokens consumed
# 2025-01-10 00:58:59,008 - WARNING - [100/7512] Error processing ASIN B0CFG8WZDJ (Attempt 1/3): HTTPSConnectionPool(host='api.keepa.com', port=443): Read timed out. (read timeout=10.0) - Retrying in 60 seconds...
# 2025-01-10 00:59:59,034 - DEBUG - Executing single product query
# 2025-01-10 00:59:59,043 - DEBUG - Estimated time to complete 1 request(s) is 0.50 minutes
# 2025-01-10 00:59:59,044 - DEBUG - 	with a refill rate of 1 token(s) per minute
# 2025-01-10 00:59:59,466 - DEBUG - 0 tokens consumed
# 2025-01-10 00:59:59,467 - WARNING - Waiting 289 seconds for additional tokens
# 2025-01-10 01:04:48,580 - DEBUG - 0 tokens consumed
# 2025-01-10 01:04:49,109 - DEBUG - 5 tokens consumed
# 100%|██████████| 1/1 [04:50<00:00, 290.09s/it]
#   0%|          | 0/1 [10:01<?, ?it/s]
# 2025-01-10 01:04:49,155 - INFO - [100/7512] Data saved for ASIN B0CFG8WZDJ
# 2025-01-10 01:05:49,179 - DEBUG - Executing single product query
# 2025-01-10 01:05:49,215 - DEBUG - Estimated time to complete 1 request(s) is 4.99 minutes
# 2025-01-10 01:05:49,216 - DEBUG - 	with a refill rate of 1 token(s) per minute
#   0%|          | 0/1 [00:00<?, ?it/s]2025-01-10 01:05:49,970 - DEBUG - 0 tokens consumed
# 2025-01-10 01:05:49,972 - WARNING - Waiting 239 seconds for additional tokens
# 2025-01-10 01:09:49,924 - DEBUG - 0 tokens consumed
# 2025-01-10 01:09:59,028 - DEBUG - 6 tokens consumed
# 100%|██████████| 1/1 [04:09<00:00, 249.87s/it]
# 2025-01-10 01:09:59,515 - INFO - [101/7512] Data saved for ASIN B015EE4D0Y
# 2025-01-10 01:10:59,531 - DEBUG - Executing single product query
# 2025-01-10 01:10:59,534 - DEBUG - Estimated time to complete 1 request(s) is 5.99 minutes
# 2025-01-10 01:10:59,535 - DEBUG - 	with a refill rate of 1 token(s) per minute
#   0%|          | 0/1 [00:00<?, ?it/s]2025-01-10 01:10:59,947 - DEBUG - 0 tokens consumed
# 2025-01-10 01:10:59,949 - WARNING - Waiting 290 seconds for additional tokens
# 2025-01-10 01:15:50,914 - DEBUG - 0 tokens consumed
# 2025-01-10 01:15:58,582 - DEBUG - 6 tokens consumed
# 100%|██████████| 1/1 [04:59<00:00, 299.11s/it]
# 2025-01-10 01:15:58,724 - INFO - [102/7512] Data saved for ASIN B0002J1FOE
# 2025-01-10 01:16:58,769 - DEBUG - Executing single product query
# 2025-01-10 01:16:58,788 - DEBUG - Estimated time to complete 1 request(s) is 5.99 minutes
# 2025-01-10 01:16:58,790 - DEBUG - 	with a refill rate of 1 token(s) per minute
#   0%|          | 0/1 [00:00<?, ?it/s]2025-01-10 01:16:59,209 - DEBUG - 0 tokens consumed
# 2025-01-10 01:16:59,210 - WARNING - Waiting 292 seconds for additional tokens
# 2025-01-10 01:21:52,073 - DEBUG - 0 tokens consumed
# 2025-01-10 01:22:01,515 - DEBUG - 6 tokens consumed
# 100%|██████████| 1/1 [05:02<00:00, 302.76s/it]
# 2025-01-10 01:22:01,588 - INFO - [103/7512] Data saved for ASIN B008572K3K
# 2025-01-10 01:23:01,626 - DEBUG - Executing single product query
# 2025-01-10 01:23:01,630 - DEBUG - Estimated time to complete 1 request(s) is 5.99 minutes
# 2025-01-10 01:23:01,631 - DEBUG - 	with a refill rate of 1 token(s) per minute
#   0%|          | 0/1 [00:00<?, ?it/s]2025-01-10 01:23:02,181 - DEBUG - 0 tokens consumed
# 2025-01-10 01:23:02,182 - WARNING - Waiting 291 seconds for additional tokens
# 2025-01-10 01:27:53,649 - DEBUG - 0 tokens consumed
# 2025-01-10 01:28:01,497 - DEBUG - 6 tokens consumed
# 100%|██████████| 1/1 [04:59<00:00, 299.92s/it]
# 2025-01-10 01:28:01,620 - INFO - [104/7512] Data saved for ASIN B003ULL1NQ
# 2025-01-10 01:29:01,644 - DEBUG - Executing single product query
# 2025-01-10 01:29:01,674 - DEBUG - Estimated time to complete 1 request(s) is 5.99 minutes
# 2025-01-10 01:29:01,675 - DEBUG - 	with a refill rate of 1 token(s) per minute
#   0%|          | 0/1 [00:00<?, ?it/s]2025-01-10 01:29:02,232 - DEBUG - 0 tokens consumed
# 2025-01-10 01:29:02,234 - WARNING - Waiting 292 seconds for additional tokens
# 2025-01-10 01:33:54,870 - DEBUG - 0 tokens consumed
# 2025-01-10 01:34:03,473 - DEBUG - 6 tokens consumed
# 100%|██████████| 1/1 [05:01<00:00, 301.82s/it]
# 2025-01-10 01:34:03,524 - INFO - [105/7512] Data saved for ASIN B08TJM5ZFW
# 2025-01-10 01:35:03,555 - DEBUG - Executing single product query
# 2025-01-10 01:35:03,568 - DEBUG - Estimated time to complete 1 request(s) is 5.99 minutes
# 2025-01-10 01:35:03,569 - DEBUG - 	with a refill rate of 1 token(s) per minute
#   0%|          | 0/1 [00:00<?, ?it/s]2025-01-10 01:35:04,168 - DEBUG - 0 tokens consumed
# 2025-01-10 01:35:04,169 - WARNING - Waiting 291 seconds for additional tokens
# 2025-01-10 01:39:56,048 - DEBUG - 0 tokens consumed
# 2025-01-10 01:40:06,361 - WARNING - [106/7512] Error processing ASIN B01N7JMRGM (Attempt 1/3): HTTPSConnectionPool(host='api.keepa.com', port=443): Read timed out. (read timeout=10.0) - Retrying in 60 seconds...
# 2025-01-10 01:41:06,394 - DEBUG - Executing single product query
# 2025-01-10 01:41:06,400 - DEBUG - Estimated time to complete 1 request(s) is 0.50 minutes
# 2025-01-10 01:41:06,401 - DEBUG - 	with a refill rate of 1 token(s) per minute
# 2025-01-10 01:41:06,854 - DEBUG - 0 tokens consumed
# 2025-01-10 01:41:06,856 - WARNING - Waiting 290 seconds for additional tokens
# 2025-01-10 01:45:57,241 - DEBUG - 0 tokens consumed
# 2025-01-10 01:45:59,252 - DEBUG - 5 tokens consumed
#   0%|          | 0/1 [10:55<?, ?it/s]
# 100%|██████████| 1/1 [04:52<00:00, 292.88s/it]
# 2025-01-10 01:45:59,316 - INFO - [106/7512] Data saved for ASIN B01N7JMRGM
# 2025-01-10 01:46:59,335 - DEBUG - Executing single product query
# 2025-01-10 01:46:59,341 - DEBUG - Estimated time to complete 1 request(s) is 4.99 minutes
# 2025-01-10 01:46:59,342 - DEBUG - 	with a refill rate of 1 token(s) per minute
#   0%|          | 0/1 [00:00<?, ?it/s]2025-01-10 01:46:59,762 - DEBUG - 0 tokens consumed
# 2025-01-10 01:46:59,765 - WARNING - Waiting 238 seconds for additional tokens
# 2025-01-10 01:50:58,503 - DEBUG - 0 tokens consumed
# 2025-01-10 01:50:59,345 - DEBUG - 5 tokens consumed
# 100%|██████████| 1/1 [04:00<00:00, 240.05s/it]
# 2025-01-10 01:50:59,430 - INFO - [107/7512] Data saved for ASIN B0BCX754DW
# 2025-01-10 01:51:59,458 - DEBUG - Executing single product query
# 2025-01-10 01:51:59,470 - DEBUG - Estimated time to complete 1 request(s) is 4.99 minutes
# 2025-01-10 01:51:59,472 - DEBUG - 	with a refill rate of 1 token(s) per minute
#   0%|          | 0/1 [00:00<?, ?it/s]2025-01-10 01:52:00,166 - DEBUG - 0 tokens consumed
# 2025-01-10 01:52:00,169 - WARNING - Waiting 239 seconds for additional tokens
# 2025-01-10 01:55:59,508 - DEBUG - 0 tokens consumed
# 2025-01-10 01:56:09,546 - DEBUG - 6 tokens consumed
# 100%|██████████| 1/1 [04:10<00:00, 250.12s/it]
# 2025-01-10 01:56:09,615 - INFO - [108/7512] Data saved for ASIN B086Y746G6
# 2025-01-10 01:57:09,636 - DEBUG - Executing single product query
# 2025-01-10 01:57:09,641 - DEBUG - Estimated time to complete 1 request(s) is 5.99 minutes
# 2025-01-10 01:57:09,643 - DEBUG - 	with a refill rate of 1 token(s) per minute
#   0%|          | 0/1 [00:00<?, ?it/s]2025-01-10 01:57:10,084 - DEBUG - 0 tokens consumed
# 2025-01-10 01:57:10,087 - WARNING - Waiting 290 seconds for additional tokens
# 2025-01-10 02:02:00,717 - DEBUG - 0 tokens consumed
# 2025-01-10 02:02:11,038 - WARNING - [109/7512] Error processing ASIN B08294GHXY (Attempt 1/3): HTTPSConnectionPool(host='api.keepa.com', port=443): Read timed out. (read timeout=10.0) - Retrying in 60 seconds...
# 2025-01-10 02:03:11,069 - DEBUG - Executing single product query
# 2025-01-10 02:03:11,074 - DEBUG - Estimated time to complete 1 request(s) is 0.50 minutes
# 2025-01-10 02:03:11,075 - DEBUG - 	with a refill rate of 1 token(s) per minute
# 2025-01-10 02:03:11,606 - DEBUG - 0 tokens consumed
# 2025-01-10 02:03:11,611 - WARNING - Waiting 290 seconds for additional tokens
# 2025-01-10 02:08:01,912 - DEBUG - 0 tokens consumed
#   0%|          | 0/1 [10:53<?, ?it/s]
# 2025-01-10 02:08:02,766 - DEBUG - 5 tokens consumed
# 100%|██████████| 1/1 [04:51<00:00, 291.72s/it]
# 2025-01-10 02:08:02,838 - INFO - [109/7512] Data saved for ASIN B08294GHXY
# 2025-01-10 02:09:02,869 - DEBUG - Executing single product query
# 2025-01-10 02:09:02,892 - DEBUG - Estimated time to complete 1 request(s) is 4.99 minutes
# 2025-01-10 02:09:02,893 - DEBUG - 	with a refill rate of 1 token(s) per minute
#   0%|          | 0/1 [00:00<?, ?it/s]2025-01-10 02:09:03,811 - DEBUG - 0 tokens consumed
# 2025-01-10 02:09:03,812 - WARNING - Waiting 239 seconds for additional tokens
# 2025-01-10 02:13:03,112 - DEBUG - 0 tokens consumed
# 2025-01-10 02:13:04,079 - DEBUG - 5 tokens consumed
# 100%|██████████| 1/1 [04:01<00:00, 241.26s/it]
# 2025-01-10 02:13:04,232 - INFO - [110/7512] Data saved for ASIN B01AMTU1ZM
# 2025-01-10 02:14:04,255 - DEBUG - Executing single product query
# 2025-01-10 02:14:04,258 - DEBUG - Estimated time to complete 1 request(s) is 4.99 minutes
# 2025-01-10 02:14:04,259 - DEBUG - 	with a refill rate of 1 token(s) per minute
#   0%|          | 0/1 [00:00<?, ?it/s]2025-01-10 02:14:04,668 - DEBUG - 0 tokens consumed
# 2025-01-10 02:14:04,670 - WARNING - Waiting 239 seconds for additional tokens
# 2025-01-10 02:18:04,268 - DEBUG - 0 tokens consumed
# 2025-01-10 02:18:12,792 - DEBUG - 6 tokens consumed
# 100%|██████████| 1/1 [04:08<00:00, 248.58s/it]
# 2025-01-10 02:18:12,865 - INFO - [111/7512] Data saved for ASIN B088BDTMW2
# 2025-01-10 02:19:12,886 - DEBUG - Executing single product query
# 2025-01-10 02:19:12,896 - DEBUG - Estimated time to complete 1 request(s) is 5.99 minutes
# 2025-01-10 02:19:12,898 - DEBUG - 	with a refill rate of 1 token(s) per minute
#   0%|          | 0/1 [00:00<?, ?it/s]2025-01-10 02:19:13,321 - DEBUG - 0 tokens consumed
# 2025-01-10 02:19:13,323 - WARNING - Waiting 292 seconds for additional tokens
# 2025-01-10 02:24:05,384 - DEBUG - 0 tokens consumed
# 2025-01-10 02:24:12,396 - DEBUG - 6 tokens consumed
# 100%|██████████| 1/1 [04:59<00:00, 299.52s/it]
# 2025-01-10 02:24:12,453 - INFO - [112/7512] Data saved for ASIN B0131GM34U
# 2025-01-10 02:25:12,465 - DEBUG - Executing single product query
# 2025-01-10 02:25:12,469 - DEBUG - Estimated time to complete 1 request(s) is 5.01 minutes
# 2025-01-10 02:25:12,470 - DEBUG - 	with a refill rate of 1 token(s) per minute
#   0%|          | 0/1 [00:00<?, ?it/s]2025-01-10 02:25:12,900 - DEBUG - 0 tokens consumed
# 2025-01-10 02:25:12,902 - WARNING - Waiting 294 seconds for additional tokens
# 2025-01-10 02:30:07,243 - DEBUG - 0 tokens consumed
# 2025-01-10 02:30:17,563 - WARNING - [113/7512] Error processing ASIN B07KX2GWTW (Attempt 1/3): HTTPSConnectionPool(host='api.keepa.com', port=443): Read timed out. (read timeout=10.0) - Retrying in 60 seconds...
# 2025-01-10 02:31:17,584 - DEBUG - Executing single product query
# 2025-01-10 02:31:17,605 - DEBUG - Estimated time to complete 1 request(s) is 0.50 minutes
# 2025-01-10 02:31:17,606 - DEBUG - 	with a refill rate of 1 token(s) per minute
# 2025-01-10 02:31:18,030 - DEBUG - 0 tokens consumed
# 2025-01-10 02:31:23,313 - DEBUG - 6 tokens consumed
# 100%|██████████| 1/1 [00:05<00:00,  5.76s/it]
#   0%|          | 0/1 [06:10<?, ?it/s]
# 2025-01-10 02:31:23,404 - INFO - [113/7512] Data saved for ASIN B07KX2GWTW
# 2025-01-10 02:32:23,436 - DEBUG - Executing single product query
# 2025-01-10 02:32:23,445 - DEBUG - Estimated time to complete 1 request(s) is 5.81 minutes
# 2025-01-10 02:32:23,446 - DEBUG - 	with a refill rate of 1 token(s) per minute
#   0%|          | 0/1 [00:00<?, ?it/s]2025-01-10 02:32:23,909 - DEBUG - 0 tokens consumed
# 2025-01-10 02:32:23,916 - WARNING - Waiting 284 seconds for additional tokens
# 2025-01-10 02:37:08,513 - DEBUG - 0 tokens consumed
# 2025-01-10 02:37:16,930 - DEBUG - 12 tokens consumed
# 100%|██████████| 1/1 [04:53<00:00, 293.55s/it]
# 2025-01-10 02:37:17,017 - INFO - [114/7512] Data saved for ASIN B0812LJ14T
# 2025-01-10 02:38:17,061 - DEBUG - Executing single product query
# 2025-01-10 02:38:17,085 - DEBUG - Estimated time to complete 1 request(s) is 11.99 minutes
# 2025-01-10 02:38:17,087 - DEBUG - 	with a refill rate of 1 token(s) per minute
#   0%|          | 0/1 [00:00<?, ?it/s]2025-01-10 02:38:17,506 - DEBUG - 0 tokens consumed
# 2025-01-10 02:38:17,508 - WARNING - Waiting 652 seconds for additional tokens
# 2025-01-10 02:49:09,862 - DEBUG - 0 tokens consumed
# Response from server: NOT_ENOUGH_TOKEN
# 2025-01-10 02:49:10,730 - DEBUG - 0 tokens consumed
# 2025-01-10 02:49:21,063 - WARNING - [115/7512] Error processing ASIN B08XY7D7BL (Attempt 1/3): HTTPSConnectionPool(host='api.keepa.com', port=443): Read timed out. (read timeout=10.0) - Retrying in 60 seconds...
# 2025-01-10 02:50:21,090 - DEBUG - Executing single product query
# 2025-01-10 02:50:21,112 - DEBUG - Estimated time to complete 1 request(s) is 0.50 minutes
# 2025-01-10 02:50:21,114 - DEBUG - 	with a refill rate of 1 token(s) per minute
# 2025-01-10 02:50:21,713 - DEBUG - 0 tokens consumed
# 2025-01-10 02:50:21,715 - WARNING - Waiting 290 seconds for additional tokens
# 2025-01-10 02:55:12,375 - DEBUG - 0 tokens consumed
#   0%|          | 0/1 [16:56<?, ?it/s]
# 2025-01-10 02:55:13,231 - DEBUG - 5 tokens consumed
# 100%|██████████| 1/1 [04:52<00:00, 292.18s/it]
# 2025-01-10 02:55:13,339 - INFO - [115/7512] Data saved for ASIN B08XY7D7BL
# 2025-01-10 02:56:13,371 - DEBUG - Executing single product query
# 2025-01-10 02:56:13,377 - DEBUG - Estimated time to complete 1 request(s) is 4.99 minutes
# 2025-01-10 02:56:13,378 - DEBUG - 	with a refill rate of 1 token(s) per minute
#   0%|          | 0/1 [00:00<?, ?it/s]2025-01-10 02:56:14,012 - DEBUG - 0 tokens consumed
# 2025-01-10 02:56:14,013 - WARNING - Waiting 239 seconds for additional tokens
# 2025-01-10 03:00:13,679 - DEBUG - 0 tokens consumed
# 2025-01-10 03:00:15,617 - DEBUG - 5 tokens consumed
# 100%|██████████| 1/1 [04:02<00:00, 242.28s/it]
# 2025-01-10 03:00:15,696 - INFO - [116/7512] Data saved for ASIN B07NF9VV22
# 2025-01-10 03:01:15,726 - DEBUG - Executing single product query
# 2025-01-10 03:01:15,751 - DEBUG - Estimated time to complete 1 request(s) is 4.99 minutes
# 2025-01-10 03:01:15,752 - DEBUG - 	with a refill rate of 1 token(s) per minute
#   0%|          | 0/1 [00:00<?, ?it/s]2025-01-10 03:01:16,178 - DEBUG - 0 tokens consumed
# 2025-01-10 03:01:16,180 - WARNING - Waiting 238 seconds for additional tokens
# 2025-01-10 03:05:14,954 - DEBUG - 0 tokens consumed
# 2025-01-10 03:05:25,051 - DEBUG - 6 tokens consumed
# 100%|██████████| 1/1 [04:09<00:00, 249.33s/it]
# 2025-01-10 03:05:25,111 - INFO - [117/7512] Data saved for ASIN B0BCXC679T
# 2025-01-10 03:06:25,147 - DEBUG - Executing single product query
# 2025-01-10 03:06:25,162 - DEBUG - Estimated time to complete 1 request(s) is 5.99 minutes
# 2025-01-10 03:06:25,163 - DEBUG - 	with a refill rate of 1 token(s) per minute
#   0%|          | 0/1 [00:00<?, ?it/s]2025-01-10 03:06:25,616 - DEBUG - 0 tokens consumed
# 2025-01-10 03:06:25,618 - WARNING - Waiting 290 seconds for additional tokens
# 2025-01-10 03:11:16,177 - DEBUG - 0 tokens consumed
# 2025-01-10 03:11:26,512 - WARNING - [118/7512] Error processing ASIN B0CYHF6PF4 (Attempt 1/3): HTTPSConnectionPool(host='api.keepa.com', port=443): Read timed out. (read timeout=10.0) - Retrying in 60 seconds...
# 2025-01-10 03:12:26,546 - DEBUG - Executing single product query
# 2025-01-10 03:12:26,558 - DEBUG - Estimated time to complete 1 request(s) is 0.50 minutes
# 2025-01-10 03:12:26,558 - DEBUG - 	with a refill rate of 1 token(s) per minute
# 2025-01-10 03:12:27,004 - DEBUG - 0 tokens consumed
# 2025-01-10 03:12:27,004 - WARNING - Waiting 290 seconds for additional tokens
# 2025-01-10 03:17:17,383 - DEBUG - 0 tokens consumed
# 2025-01-10 03:17:18,012 - DEBUG - 5 tokens consumed
#   0%|          | 0/1 [10:52<?, ?it/s]
# 100%|██████████| 1/1 [04:51<00:00, 291.49s/it]
# 2025-01-10 03:17:18,072 - INFO - [118/7512] Data saved for ASIN B0CYHF6PF4
# 2025-01-10 03:18:18,087 - DEBUG - Executing single product query
# 2025-01-10 03:18:18,092 - DEBUG - Estimated time to complete 1 request(s) is 4.99 minutes
# 2025-01-10 03:18:18,093 - DEBUG - 	with a refill rate of 1 token(s) per minute
#   0%|          | 0/1 [00:00<?, ?it/s]2025-01-10 03:18:19,105 - DEBUG - 0 tokens consumed
# 2025-01-10 03:18:19,105 - WARNING - Waiting 239 seconds for additional tokens
# 2025-01-10 03:22:18,567 - DEBUG - 0 tokens consumed
# 2025-01-10 03:22:25,273 - DEBUG - 6 tokens consumed
# 100%|██████████| 1/1 [04:07<00:00, 247.24s/it]
# 2025-01-10 03:22:25,371 - INFO - [119/7512] Data saved for ASIN B0021WZPWI
# 2025-01-10 03:23:25,405 - DEBUG - Executing single product query
# 2025-01-10 03:23:25,420 - DEBUG - Estimated time to complete 1 request(s) is 5.99 minutes
# 2025-01-10 03:23:25,421 - DEBUG - 	with a refill rate of 1 token(s) per minute
#   0%|          | 0/1 [00:00<?, ?it/s]2025-01-10 03:23:25,844 - DEBUG - 0 tokens consumed
# 2025-01-10 03:23:25,844 - WARNING - Waiting 293 seconds for additional tokens
# 2025-01-10 03:28:19,566 - DEBUG - 0 tokens consumed
# 2025-01-10 03:28:29,890 - WARNING - [120/7512] Error processing ASIN B01BV4IMK8 (Attempt 1/3): HTTPSConnectionPool(host='api.keepa.com', port=443): Read timed out. (read timeout=10.0) - Retrying in 60 seconds...
# 2025-01-10 03:29:29,912 - DEBUG - Executing single product query
# 2025-01-10 03:29:29,926 - DEBUG - Estimated time to complete 1 request(s) is 0.50 minutes
# 2025-01-10 03:29:29,928 - DEBUG - 	with a refill rate of 1 token(s) per minute
# 2025-01-10 03:29:30,378 - DEBUG - 0 tokens consumed
# 2025-01-10 03:29:30,380 - WARNING - Waiting 290 seconds for additional tokens
# 2025-01-10 03:34:20,746 - DEBUG - 0 tokens consumed
# 2025-01-10 03:34:31,088 - WARNING - [120/7512] Error processing ASIN B01BV4IMK8 (Attempt 2/3): HTTPSConnectionPool(host='api.keepa.com', port=443): Read timed out. (read timeout=10.0) - Retrying in 60 seconds...
# 2025-01-10 03:35:31,127 - DEBUG - Executing single product query
# 2025-01-10 03:35:31,168 - DEBUG - Estimated time to complete 1 request(s) is 0.50 minutes
# 2025-01-10 03:35:31,169 - DEBUG - 	with a refill rate of 1 token(s) per minute
#
# 2025-01-10 03:35:31,644 - DEBUG - 0 tokens consumed
# 2025-01-10 03:35:31,646 - WARNING - Waiting 230 seconds for additional tokens
# 2025-01-10 03:39:22,021 - DEBUG - 0 tokens consumed
# 2025-01-10 03:39:32,360 - ERROR - [120/7512] Error processing ASIN B01BV4IMK8 (Attempt 3/3): HTTPSConnectionPool(host='api.keepa.com', port=443): Read timed out. (read timeout=10.0)
# 2025-01-10 03:39:32,383 - DEBUG - Executing single product query
# 2025-01-10 03:39:32,384 - DEBUG - Estimated time to complete 1 request(s) is 0.50 minutes
# 2025-01-10 03:39:32,386 - DEBUG - 	with a refill rate of 1 token(s) per minute
#
#
#   0%|          | 0/1 [16:06<?, ?it/s]
#   0%|          | 0/1 [10:02<?, ?it/s]
#   0%|          | 0/1 [04:01<?, ?it/s]
# 2025-01-10 03:39:32,807 - DEBUG - 0 tokens consumed
# 2025-01-10 03:39:32,808 - WARNING - Waiting 350 seconds for additional tokens
# 2025-01-10 03:45:22,771 - DEBUG - 0 tokens consumed
# 2025-01-10 03:45:23,765 - DEBUG - 5 tokens consumed
#
#
# 100%|██████████| 1/1 [05:51<00:00, 351.51s/it]
# 2025-01-10 03:45:24,020 - INFO - [121/7512] Data saved for ASIN B0718YFR4K
# 2025-01-10 03:46:24,044 - DEBUG - Executing single product query
# 2025-01-10 03:46:24,061 - DEBUG - Estimated time to complete 1 request(s) is 5.00 minutes
# 2025-01-10 03:46:24,062 - DEBUG - 	with a refill rate of 1 token(s) per minute
#   0%|          | 0/1 [00:00<?, ?it/s]2025-01-10 03:46:24,637 - DEBUG - 0 tokens consumed
# 2025-01-10 03:46:24,639 - WARNING - Waiting 239 seconds for additional tokens
# 2025-01-10 03:50:24,330 - DEBUG - 0 tokens consumed
# 2025-01-10 03:50:33,166 - DEBUG - 1 tokens consumed
# 100%|██████████| 1/1 [04:09<00:00, 249.14s/it]
# 2025-01-10 03:50:33,238 - INFO - [122/7512] Data saved for ASIN B08QYRK4XY
# 2025-01-10 03:51:33,307 - DEBUG - Executing single product query
# 2025-01-10 03:51:33,322 - DEBUG - Estimated time to complete 1 request(s) is 0.99 minutes
# 2025-01-10 03:51:33,323 - DEBUG - 	with a refill rate of 1 token(s) per minute
#   0%|          | 0/1 [00:00<?, ?it/s]2025-01-10 03:51:33,762 - DEBUG - 0 tokens consumed
# 2025-01-10 03:51:34,913 - DEBUG - 5 tokens consumed
# 100%|██████████| 1/1 [00:01<00:00,  1.61s/it]
# 2025-01-10 03:51:34,954 - INFO - [123/7512] Data saved for ASIN B09BD9F63B
# 2025-01-10 03:52:34,979 - DEBUG - Executing single product query
# 2025-01-10 03:52:34,994 - DEBUG - Estimated time to complete 1 request(s) is 4.84 minutes
# 2025-01-10 03:52:34,996 - DEBUG - 	with a refill rate of 1 token(s) per minute
#   0%|          | 0/1 [00:00<?, ?it/s]2025-01-10 03:52:35,427 - DEBUG - 0 tokens consumed
# 2025-01-10 03:52:35,430 - WARNING - Waiting 230 seconds for additional tokens
# 2025-01-10 03:56:25,507 - DEBUG - 0 tokens consumed
# 2025-01-10 03:56:26,511 - DEBUG - 1 tokens consumed
# 100%|██████████| 1/1 [03:51<00:00, 231.57s/it]
# 2025-01-10 03:56:26,765 - INFO - [124/7512] Data saved for ASIN B003CL3PTM
# 2025-01-10 03:57:26,785 - DEBUG - Executing single product query
# 2025-01-10 03:57:26,810 - DEBUG - Estimated time to complete 1 request(s) is 0.99 minutes
# 2025-01-10 03:57:26,811 - DEBUG - 	with a refill rate of 1 token(s) per minute
#   0%|          | 0/1 [00:00<?, ?it/s]2025-01-10 03:57:27,783 - DEBUG - 0 tokens consumed
# 2025-01-10 03:57:28,645 - DEBUG - 1 tokens consumed
# 100%|██████████| 1/1 [00:01<00:00,  1.89s/it]
# 2025-01-10 03:57:28,742 - INFO - [125/7512] Data saved for ASIN B0002DGRSY
# 2025-01-10 03:58:28,770 - DEBUG - Executing single product query
# 2025-01-10 03:58:28,789 - DEBUG - Estimated time to complete 1 request(s) is 0.96 minutes
# 2025-01-10 03:58:28,791 - DEBUG - 	with a refill rate of 1 token(s) per minute
#   0%|          | 0/1 [00:00<?, ?it/s]2025-01-10 03:58:29,443 - DEBUG - 0 tokens consumed
# 2025-01-10 03:58:39,765 - WARNING - [126/7512] Error processing ASIN B089RGQRXN (Attempt 1/3): HTTPSConnectionPool(host='api.keepa.com', port=443): Read timed out. (read timeout=10.0) - Retrying in 60 seconds...
# 2025-01-10 03:59:39,783 - DEBUG - Executing single product query
# 2025-01-10 03:59:39,799 - DEBUG - Estimated time to complete 1 request(s) is 0.50 minutes
# 2025-01-10 03:59:39,800 - DEBUG - 	with a refill rate of 1 token(s) per minute
# 2025-01-10 03:59:40,257 - DEBUG - 0 tokens consumed
# 2025-01-10 03:59:40,258 - WARNING - Waiting 286 seconds for additional tokens
# 2025-01-10 04:04:27,119 - DEBUG - 0 tokens consumed
# 2025-01-10 04:04:27,826 - DEBUG - 5 tokens consumed
# 100%|██████████| 1/1 [04:48<00:00, 288.06s/it]
#   0%|          | 0/1 [05:59<?, ?it/s]
# 2025-01-10 04:04:27,884 - INFO - [126/7512] Data saved for ASIN B089RGQRXN
# 2025-01-10 04:05:27,902 - DEBUG - Executing single product query
# 2025-01-10 04:05:27,924 - DEBUG - Estimated time to complete 1 request(s) is 5.00 minutes
# 2025-01-10 04:05:27,926 - DEBUG - 	with a refill rate of 1 token(s) per minute
#   0%|          | 0/1 [00:00<?, ?it/s]2025-01-10 04:05:28,362 - DEBUG - 0 tokens consumed
# 2025-01-10 04:05:28,364 - WARNING - Waiting 240 seconds for additional tokens
# 2025-01-10 04:09:28,628 - DEBUG - 0 tokens consumed
# ...
# 2025-01-10 07:02:19,142 - DEBUG - 0 tokens consumed
# 2025-01-10 07:02:19,145 - WARNING - Waiting 286 seconds for additional tokens
# 2025-01-10 07:07:05,682 - DEBUG - 0 tokens consumed
# 2025-01-10 07:07:06,508 - DEBUG - 5 tokens consumed
#   0%|          | 0/1 [05:58<?, ?it/s]
# 100%|██████████| 1/1 [04:47<00:00, 287.84s/it]
# 2025-01-10 07:07:06,589 - INFO - [150/7512] Data saved for ASIN B00D5ZTWRE
# 2025-01-10 07:08:06,615 - DEBUG - Executing single product query
# 2025-01-10 07:08:06,630 - DEBUG - Estimated time to complete 1 request(s) is 4.99 minutes
# 2025-01-10 07:08:06,631 - DEBUG - 	with a refill rate of 1 token(s) per minute
#   0%|          | 0/1 [00:00<?, ?it/s]2025-01-10 07:08:07,504 - DEBUG - 0 tokens consumed
# 2025-01-10 07:08:07,505 - WARNING - Waiting 239 seconds for additional tokens
# 2025-01-10 07:12:06,955 - DEBUG - 0 tokens consumed
# 2025-01-10 07:12:15,763 - DEBUG - 6 tokens consumed
# 100%|██████████| 1/1 [04:09<00:00, 249.17s/it]
# 2025-01-10 07:12:15,825 - INFO - [151/7512] Data saved for ASIN B07VC2SLTH
# 2025-01-10 07:13:15,852 - DEBUG - Executing single product query
# 2025-01-10 07:13:15,864 - DEBUG - Estimated time to complete 1 request(s) is 5.99 minutes
# 2025-01-10 07:13:15,865 - DEBUG - 	with a refill rate of 1 token(s) per minute
#   0%|          | 0/1 [00:00<?, ?it/s]2025-01-10 07:13:16,290 - DEBUG - 0 tokens consumed
# 2025-01-10 07:13:16,291 - WARNING - Waiting 291 seconds for additional tokens
# 2025-01-10 07:18:07,916 - DEBUG - 0 tokens consumed
# 2025-01-10 07:18:08,894 - DEBUG - 5 tokens consumed
# 100%|██████████| 1/1 [04:53<00:00, 293.07s/it]
# 2025-01-10 07:18:08,960 - INFO - [152/7512] Data saved for ASIN B07F2MHBR2
# 2025-01-10 07:19:08,983 - DEBUG - Executing single product query
# 2025-01-10 07:19:09,005 - DEBUG - Estimated time to complete 1 request(s) is 5.00 minutes
# 2025-01-10 07:19:09,006 - DEBUG - 	with a refill rate of 1 token(s) per minute
#   0%|          | 0/1 [00:00<?, ?it/s]2025-01-10 07:19:09,694 - DEBUG - 0 tokens consumed
# 2025-01-10 07:19:09,695 - WARNING - Waiting 239 seconds for additional tokens
# 2025-01-10 07:23:09,412 - DEBUG - 0 tokens consumed
# 2025-01-10 07:23:16,769 - DEBUG - 6 tokens consumed
# 100%|██████████| 1/1 [04:07<00:00, 247.81s/it]
# 2025-01-10 07:23:16,857 - INFO - [153/7512] Data saved for ASIN B0000AH3QT
# 2025-01-10 07:24:16,902 - DEBUG - Executing single product query
# 2025-01-10 07:24:16,909 - DEBUG - Estimated time to complete 1 request(s) is 5.99 minutes
# 2025-01-10 07:24:16,910 - DEBUG - 	with a refill rate of 1 token(s) per minute
#   0%|          | 0/1 [00:00<?, ?it/s]2025-01-10 07:24:17,327 - DEBUG - 0 tokens consumed
# 2025-01-10 07:24:17,329 - WARNING - Waiting 293 seconds for additional tokens
# 2025-01-10 07:29:10,686 - DEBUG - 0 tokens consumed
# 2025-01-10 07:29:17,476 - DEBUG - 12 tokens consumed
# 100%|██████████| 1/1 [05:00<00:00, 300.63s/it]
# 2025-01-10 07:29:17,598 - INFO - [154/7512] Data saved for ASIN B00BGWA8OE
# 2025-01-10 07:30:17,624 - DEBUG - Executing single product query
# 2025-01-10 07:30:17,630 - DEBUG - Estimated time to complete 1 request(s) is 11.99 minutes
# 2025-01-10 07:30:17,631 - DEBUG - 	with a refill rate of 1 token(s) per minute
#   0%|          | 0/1 [00:00<?, ?it/s]2025-01-10 07:30:18,072 - DEBUG - 0 tokens consumed
# 2025-01-10 07:30:18,075 - WARNING - Waiting 653 seconds for additional tokens
# 2025-01-10 07:41:11,880 - DEBUG - 0 tokens consumed
# Response from server: NOT_ENOUGH_TOKEN
# 2025-01-10 07:41:12,731 - DEBUG - 0 tokens consumed
# 2025-01-10 07:41:21,791 - DEBUG - 6 tokens consumed
# 100%|██████████| 1/1 [11:04<00:00, 664.19s/it]
# 2025-01-10 07:41:21,857 - INFO - [155/7512] Data saved for ASIN B0C1HG6XC8
# 2025-01-10 07:42:21,873 - DEBUG - Executing single product query
# 2025-01-10 07:42:21,883 - DEBUG - Estimated time to complete 1 request(s) is 6.00 minutes
# 2025-01-10 07:42:21,884 - DEBUG - 	with a refill rate of 1 token(s) per minute
#   0%|          | 0/1 [00:00<?, ?it/s]2025-01-10 07:42:22,323 - DEBUG - 0 tokens consumed
# 2025-01-10 07:42:22,325 - WARNING - Waiting 291 seconds for additional tokens
# 2025-01-10 07:47:14,201 - DEBUG - 0 tokens consumed
# 2025-01-10 07:47:22,255 - DEBUG - 6 tokens consumed
# 100%|██████████| 1/1 [05:00<00:00, 300.41s/it]
# 2025-01-10 07:47:22,336 - INFO - [156/7512] Data saved for ASIN B006HX5PNQ
# 2025-01-10 07:48:22,351 - DEBUG - Executing single product query
# 2025-01-10 07:48:22,356 - DEBUG - Estimated time to complete 1 request(s) is 5.99 minutes
# 2025-01-10 07:48:22,357 - DEBUG - 	with a refill rate of 1 token(s) per minute
#   0%|          | 0/1 [00:00<?, ?it/s]2025-01-10 07:48:22,834 - DEBUG - 0 tokens consumed
# 2025-01-10 07:48:22,836 - WARNING - Waiting 292 seconds for additional tokens
# 2025-01-10 07:53:15,441 - DEBUG - 0 tokens consumed
# 2025-01-10 07:53:16,488 - DEBUG - 5 tokens consumed
# 100%|██████████| 1/1 [04:54<00:00, 294.20s/it]
# 2025-01-10 07:53:16,641 - INFO - [157/7512] Data saved for ASIN B003O7ZON4
# 2025-01-10 07:54:16,669 - DEBUG - Executing single product query
# 2025-01-10 07:54:16,685 - DEBUG - Estimated time to complete 1 request(s) is 4.99 minutes
# 2025-01-10 07:54:16,687 - DEBUG - 	with a refill rate of 1 token(s) per minute
#   0%|          | 0/1 [00:00<?, ?it/s]2025-01-10 07:54:17,101 - DEBUG - 0 tokens consumed
# 2025-01-10 07:54:17,103 - WARNING - Waiting 239 seconds for additional tokens
# 2025-01-10 07:58:16,701 - DEBUG - 0 tokens consumed
# 2025-01-10 07:58:24,163 - DEBUG - 6 tokens consumed
# 100%|██████████| 1/1 [04:07<00:00, 247.51s/it]
# 2025-01-10 07:58:24,243 - INFO - [158/7512] Data saved for ASIN B004XLBVGE
# 2025-01-10 07:59:24,267 - DEBUG - Executing single product query
# 2025-01-10 07:59:24,272 - DEBUG - Estimated time to complete 1 request(s) is 5.99 minutes
# 2025-01-10 07:59:24,273 - DEBUG - 	with a refill rate of 1 token(s) per minute
#   0%|          | 0/1 [00:00<?, ?it/s]2025-01-10 07:59:24,703 - DEBUG - 0 tokens consumed
# 2025-01-10 07:59:24,706 - WARNING - Waiting 293 seconds for additional tokens
# 2025-01-10 08:04:17,767 - DEBUG - 0 tokens consumed
# 2025-01-10 08:04:23,787 - DEBUG - 6 tokens consumed
# 100%|██████████| 1/1 [04:59<00:00, 299.56s/it]
# 2025-01-10 08:04:23,862 - INFO - [159/7512] Data saved for ASIN B00IYI0LR2
# 2025-01-10 08:05:23,878 - DEBUG - Executing single product query
# 2025-01-10 08:05:23,892 - DEBUG - Estimated time to complete 1 request(s) is 5.99 minutes
# 2025-01-10 08:05:23,893 - DEBUG - 	with a refill rate of 1 token(s) per minute
#   0%|          | 0/1 [00:00<?, ?it/s]2025-01-10 08:05:24,346 - DEBUG - 0 tokens consumed
# 2025-01-10 08:05:24,348 - WARNING - Waiting 294 seconds for additional tokens
# 2025-01-10 08:10:18,992 - DEBUG - 0 tokens consumed
# 2025-01-10 08:10:25,231 - DEBUG - 6 tokens consumed
# 100%|██████████| 1/1 [05:01<00:00, 301.37s/it]
# 2025-01-10 08:10:25,289 - INFO - [160/7512] Data saved for ASIN B0BPW8G3VR
# 2025-01-10 08:11:25,318 - DEBUG - Executing single product query
# 2025-01-10 08:11:25,324 - DEBUG - Estimated time to complete 1 request(s) is 5.99 minutes
# 2025-01-10 08:11:25,325 - DEBUG - 	with a refill rate of 1 token(s) per minute
#   0%|          | 0/1 [00:00<?, ?it/s]2025-01-10 08:11:25,752 - DEBUG - 0 tokens consumed
# 2025-01-10 08:11:25,755 - WARNING - Waiting 294 seconds for additional tokens
# 2025-01-10 08:16:20,365 - DEBUG - 0 tokens consumed
# 2025-01-10 08:16:26,108 - DEBUG - 6 tokens consumed
# 100%|██████████| 1/1 [05:00<00:00, 300.81s/it]
# 2025-01-10 08:16:26,153 - INFO - [161/7512] Data saved for ASIN B0BW3CVN3V
# 2025-01-10 08:17:26,172 - DEBUG - Executing single product query
# 2025-01-10 08:17:26,183 - DEBUG - Estimated time to complete 1 request(s) is 5.99 minutes
# 2025-01-10 08:17:26,185 - DEBUG - 	with a refill rate of 1 token(s) per minute
#   0%|          | 0/1 [00:00<?, ?it/s]2025-01-10 08:17:26,602 - DEBUG - 0 tokens consumed
# 2025-01-10 08:17:26,604 - WARNING - Waiting 294 seconds for additional tokens
# 2025-01-10 08:22:21,526 - DEBUG - 0 tokens consumed
# 2025-01-10 08:22:28,324 - DEBUG - 6 tokens consumed
# 100%|██████████| 1/1 [05:02<00:00, 302.19s/it]
# 2025-01-10 08:22:28,426 - INFO - [162/7512] Data saved for ASIN B000PKWKMQ
# 2025-01-10 08:23:28,470 - DEBUG - Executing single product query
# 2025-01-10 08:23:28,494 - DEBUG - Estimated time to complete 1 request(s) is 6.00 minutes
# 2025-01-10 08:23:28,495 - DEBUG - 	with a refill rate of 1 token(s) per minute
#   0%|          | 0/1 [00:00<?, ?it/s]2025-01-10 08:23:28,950 - DEBUG - 0 tokens consumed
# 2025-01-10 08:23:28,951 - WARNING - Waiting 294 seconds for additional tokens
# 2025-01-10 08:28:22,941 - DEBUG - 0 tokens consumed
# 2025-01-10 08:28:24,019 - DEBUG - 5 tokens consumed
# 100%|██████████| 1/1 [04:55<00:00, 295.57s/it]
# 2025-01-10 08:28:24,103 - INFO - [163/7512] Data saved for ASIN B0081Z77LG
# 2025-01-10 08:29:24,147 - DEBUG - Executing single product query
# 2025-01-10 08:29:24,171 - DEBUG - Estimated time to complete 1 request(s) is 4.99 minutes
# 2025-01-10 08:29:24,172 - DEBUG - 	with a refill rate of 1 token(s) per minute
#   0%|          | 0/1 [00:00<?, ?it/s]2025-01-10 08:29:24,590 - DEBUG - 0 tokens consumed
# 2025-01-10 08:29:24,591 - WARNING - Waiting 239 seconds for additional tokens
# 2025-01-10 08:33:24,178 - DEBUG - 0 tokens consumed
# 2025-01-10 08:33:34,981 - DEBUG - 6 tokens consumed
# 100%|██████████| 1/1 [04:10<00:00, 250.88s/it]
# 2025-01-10 08:33:35,125 - INFO - [164/7512] Data saved for ASIN B00006IX59
# 2025-01-10 08:34:35,146 - DEBUG - Executing single product query
# 2025-01-10 08:34:35,165 - DEBUG - Estimated time to complete 1 request(s) is 5.99 minutes
# 2025-01-10 08:34:35,167 - DEBUG - 	with a refill rate of 1 token(s) per minute
#   0%|          | 0/1 [00:00<?, ?it/s]2025-01-10 08:34:35,581 - DEBUG - 0 tokens consumed
# 2025-01-10 08:34:35,584 - WARNING - Waiting 289 seconds for additional tokens
# 2025-01-10 08:39:25,140 - DEBUG - 0 tokens consumed
# 2025-01-10 08:39:32,445 - DEBUG - 6 tokens consumed
# 100%|██████████| 1/1 [04:57<00:00, 297.32s/it]
# 2025-01-10 08:39:32,518 - INFO - [165/7512] Data saved for ASIN B07KGY1F9Q
# 2025-01-10 08:40:32,546 - DEBUG - Executing single product query
# 2025-01-10 08:40:32,567 - DEBUG - Estimated time to complete 1 request(s) is 5.99 minutes
# 2025-01-10 08:40:32,570 - DEBUG - 	with a refill rate of 1 token(s) per minute
#   0%|          | 0/1 [00:00<?, ?it/s]2025-01-10 08:40:33,016 - DEBUG - 0 tokens consumed
# 2025-01-10 08:40:33,018 - WARNING - Waiting 293 seconds for additional tokens
# 2025-01-10 08:45:26,358 - DEBUG - 0 tokens consumed
# 2025-01-10 08:45:33,716 - DEBUG - 6 tokens consumed
# 100%|██████████| 1/1 [05:01<00:00, 301.22s/it]
# 2025-01-10 08:45:33,847 - INFO - [166/7512] Data saved for ASIN B00280MUJY
# 2025-01-10 08:46:34,309 - DEBUG - Executing single product query
# 2025-01-10 08:46:34,655 - DEBUG - Estimated time to complete 1 request(s) is 5.99 minutes
# 2025-01-10 08:46:34,671 - DEBUG - 	with a refill rate of 1 token(s) per minute
#   0%|          | 0/1 [00:00<?, ?it/s]2025-01-10 08:46:35,794 - DEBUG - 0 tokens consumed
# 2025-01-10 08:46:35,858 - WARNING - Waiting 291 seconds for additional tokens
# 2025-01-10 08:51:27,724 - DEBUG - 0 tokens consumed
# 2025-01-10 08:51:37,664 - DEBUG - 6 tokens consumed
# 100%|██████████| 1/1 [05:02<00:00, 302.95s/it]
# 2025-01-10 08:51:37,780 - INFO - [167/7512] Data saved for ASIN B010IGL3QA
# 2025-01-10 08:52:37,816 - DEBUG - Executing single product query
# 2025-01-10 08:52:37,821 - DEBUG - Estimated time to complete 1 request(s) is 5.99 minutes
# 2025-01-10 08:52:37,822 - DEBUG - 	with a refill rate of 1 token(s) per minute
#   0%|          | 0/1 [00:00<?, ?it/s]2025-01-10 08:52:38,250 - DEBUG - 0 tokens consumed
# 2025-01-10 08:52:38,251 - WARNING - Waiting 290 seconds for additional tokens
# 2025-01-10 08:57:28,848 - DEBUG - 0 tokens consumed
# 2025-01-10 08:57:38,839 - DEBUG - 6 tokens consumed
# 100%|██████████| 1/1 [05:01<00:00, 301.09s/it]
# 2025-01-10 08:57:38,961 - INFO - [168/7512] Data saved for ASIN B001B4TV1I
# 2025-01-10 08:58:39,015 - DEBUG - Executing single product query
# 2025-01-10 08:58:39,037 - DEBUG - Estimated time to complete 1 request(s) is 6.00 minutes
# 2025-01-10 08:58:39,039 - DEBUG - 	with a refill rate of 1 token(s) per minute
#   0%|          | 0/1 [00:00<?, ?it/s]2025-01-10 08:58:39,497 - DEBUG - 0 tokens consumed
# 2025-01-10 08:58:39,499 - WARNING - Waiting 290 seconds for additional tokens
# 2025-01-10 09:03:30,283 - DEBUG - 0 tokens consumed
# 2025-01-10 09:03:33,037 - DEBUG - 1 tokens consumed
# 100%|██████████| 1/1 [04:54<00:00, 294.07s/it]
# 2025-01-10 09:03:33,196 - INFO - [169/7512] Data saved for ASIN B00027465G
# 2025-01-10 09:04:33,209 - DEBUG - Executing single product query
# 2025-01-10 09:04:33,215 - DEBUG - Estimated time to complete 1 request(s) is 0.99 minutes
# 2025-01-10 09:04:33,216 - DEBUG - 	with a refill rate of 1 token(s) per minute
#   0%|          | 0/1 [00:00<?, ?it/s]2025-01-10 09:04:33,642 - DEBUG - 0 tokens consumed
# 2025-01-10 09:04:39,295 - DEBUG - 6 tokens consumed
# 100%|██████████| 1/1 [00:06<00:00,  6.11s/it]
# 2025-01-10 09:04:39,359 - INFO - [170/7512] Data saved for ASIN B00CI50JFG
# 2025-01-10 09:05:39,383 - DEBUG - Executing single product query
# 2025-01-10 09:05:39,399 - DEBUG - Estimated time to complete 1 request(s) is 5.94 minutes
# 2025-01-10 09:05:39,400 - DEBUG - 	with a refill rate of 1 token(s) per minute
#   0%|          | 0/1 [00:00<?, ?it/s]2025-01-10 09:05:40,937 - DEBUG - 0 tokens consumed
# 2025-01-10 09:05:40,939 - WARNING - Waiting 290 seconds for additional tokens
# 2025-01-10 09:10:32,764 - DEBUG - 0 tokens consumed
# 2025-01-10 09:10:43,102 - WARNING - [171/7512] Error processing ASIN B075LTG2Q5 (Attempt 1/3): HTTPSConnectionPool(host='api.keepa.com', port=443): Read timed out. (read timeout=10.0) - Retrying in 60 seconds...
# 2025-01-10 09:11:43,126 - DEBUG - Executing single product query
# 2025-01-10 09:11:43,131 - DEBUG - Estimated time to complete 1 request(s) is 0.50 minutes
# 2025-01-10 09:11:43,133 - DEBUG - 	with a refill rate of 1 token(s) per minute
# 2025-01-10 09:11:43,570 - DEBUG - 0 tokens consumed
# 2025-01-10 09:11:43,573 - WARNING - Waiting 289 seconds for additional tokens
# 2025-01-10 09:16:32,892 - DEBUG - 0 tokens consumed
# 2025-01-10 09:16:34,638 - DEBUG - 5 tokens consumed
#   0%|          | 0/1 [10:55<?, ?it/s]
# 100%|██████████| 1/1 [04:51<00:00, 291.57s/it]
# 2025-01-10 09:16:34,750 - INFO - [171/7512] Data saved for ASIN B075LTG2Q5
# 2025-01-10 09:17:34,768 - DEBUG - Executing single product query
# 2025-01-10 09:17:34,792 - DEBUG - Estimated time to complete 1 request(s) is 4.01 minutes
# 2025-01-10 09:17:34,796 - DEBUG - 	with a refill rate of 1 token(s) per minute
#   0%|          | 0/1 [00:00<?, ?it/s]2025-01-10 09:17:35,242 - DEBUG - 0 tokens consumed
# 2025-01-10 09:17:35,244 - WARNING - Waiting 239 seconds for additional tokens
# 2025-01-10 09:21:34,508 - DEBUG - 0 tokens consumed
# 2025-01-10 09:21:44,830 - WARNING - [172/7512] Error processing ASIN B08C3X6Y2F (Attempt 1/3): HTTPSConnectionPool(host='api.keepa.com', port=443): Read timed out. (read timeout=10.0) - Retrying in 60 seconds...
# 2025-01-10 09:22:44,851 - DEBUG - Executing single product query
# 2025-01-10 09:22:44,856 - DEBUG - Estimated time to complete 1 request(s) is 0.50 minutes
# 2025-01-10 09:22:44,858 - DEBUG - 	with a refill rate of 1 token(s) per minute
# 2025-01-10 09:22:45,287 - DEBUG - 0 tokens consumed
# 2025-01-10 09:22:52,823 - DEBUG - 6 tokens consumed
#   0%|          | 0/1 [05:18<?, ?it/s]
# 100%|██████████| 1/1 [00:08<00:00,  8.01s/it]
# 2025-01-10 09:22:52,927 - INFO - [172/7512] Data saved for ASIN B08C3X6Y2F
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[7], line 6
#       4 if asins:
#       5     logging.info(f"Starting download for {len(asins)} ASINs...")
# ----> 6     download_product_data(asins)
#       7     logging.info("Download process completed!")
#
# Cell In[5], line 99, in download_product_data(asins, max_retries, retry_delay)
#      96     save_progress(progress)
#      98     # Sleep to respect API limits (1 token per minute)
# ---> 99     time.sleep(60)
#     100     break
#     102 except Exception as e:
#
# KeyboardInterrupt:
